# %%
import os
import json

# %%
directory = '../manual_tweets/'

inactive = 0
totalusers = 0
users = 0

for filename in os.listdir(directory):
    print(filename)
    filename = directory+filename
    totalusers += 1
    
    
    with open(filename, "r") as tweets_file:
        numtweets = 0
        #for line in tweets_file:
        #    print(line)
        #    try:
        #        numtweets += 1
                # Read in one line of the file, convert it into a json object 
        #        tweet = json.loads(line.strip())
                #if 'text' in tweet: # only messages contains 'text' field is a tweet
                    #print tweet['id'] # This is the tweet's id
                    #print tweet['created_at'] # when the tweet posted
                    #print tweet['text'] # content of the tweet

                    #print tweet['user']['id'] # id of the user who posted the tweet
                    #print tweet['user']['name'] # name of the user, e.g. "Wei Xu"
                    #print tweet['user']['screen_name'] # name of the user account, e.g. "cocoweixu"
         #   except:
                #print("no json: user inactive")
         #       inactive += 1
         #       continue

         #   numtweets += 1

          #  if numtweets >= 5:
          #      break

        #users = users + numtweets
            
    

print(users)
print(inactive, " number of inactive users")
print(totalusers, " number of total users")
print(totalusers - inactive, " number of users in manual set")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
directory = '../manual_tweets/'

inactive = 0
totalusers = 0
users = 0

filenames = []

for filename in os.listdir(directory):
    filename = directory+filename
    totalusers += 1
    
    filenames.append(filename)
    

print filenames[0]
with open(filenames[0], "r") as tweets_file:
    for line in tweets_file:
        print line
    #tweet = json.loads(tweets_file)

    
    

print(totalusers, " number of total users")
# Out:
# ../manual_tweets/@0154_GUTIERREZ.txt
# (12310, ' number of total users')

# %%
directory = '../manual_tweets/'

filename = '@_baiibai.txt'

filename = directory+filename

data = []
numlines = 0

with open(filename, "r") as tweets_file:
    for line in tweets_file:
        print line
        #tweet = json.loads(line)
        
        #data.append(json.loads(line))
# Out:
# {"contributors": null, "truncated": false, "text": "@SAVINGEZRA YESSSSS\ud83d\ude06\ud83d\ude06", "is_quote_status": false, "in_reply_to_status_id": 817060145805062144, "id": 817063217235103744, "favorite_count": 0, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [{"id": 827728690800893953, "indices": [0, 11], "id_str": "827728690800893953", "screen_name": "savingezra", "name": "Robert Kinsella \ud83c\udf83"}], "hashtags": [], "urls": []}, "in_reply_to_screen_name": "EZRAPolitics", "in_reply_to_user_id": 110881593, "retweet_count": 0, "id_str": "817063217235103744", "favorited": false, "user": {"follow_request_sent": false, "has_extended_profile": true, "profile_use_background_image": true, "default_profile_image": false, "id": 3235321188, "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "verified": false
# ...

# %%
#from json import JSONDecoder, JSONDecodeError
from simplejson.scanner import JSONDecodeError
import re

NOT_WHITESPACE = re.compile(r'[^\s]')

def decode_stacked(document, pos=0, decoder=JSONDecoder()):
    while True:
        match = NOT_WHITESPACE.search(document, pos)
        if not match:
            return
        pos = match.start()

        try:
            obj, pos = decoder.raw_decode(document, pos)
        except JSONDecodeError:
            # do something sensible if there's some error
            raise
        yield obj

#s = """
#
#{"a": 1}  


#   [
#1
#,   
#2
#]


#"""

for obj in decode_stacked(s):
    print(obj)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-efa691d2cd40> in <module>()
#      33 #"""
#      34
# ---> 35 for obj in decode_stacked(s):
#      36     print(obj)
#
# <ipython-input-46-efa691d2cd40> in decode_stacked(document, pos, decoder)
#      13
#      14         try:
# ---> 15             obj, pos = decoder.raw_decode(document, pos)
#      16         except JSONDecodeError:
#      17             # do something sensible if there's some error
#
# C:\Users\madim\Anaconda2\lib\json\decoder.pyc in raw_decode(self, s, idx)
#     378         """
#     379         try:
# --> 380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
#     382             raise ValueError("No JSON object could be decoded")
#
# ValueError: Expecting , delimiter: line 11 column 22 (char 250)

# %%
s = '''

{
    "contributors": null,
	"truncated": false,
	"text": "@SAVINGEZRA YESSSSS\ud83d\ude06\ud83d\ude06",
	"is_quote_status": false,
	"in_reply_to_status_id": 817060145805062144,
	"id": 817063217235103744,
	"favorite_count": 0,
	"source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
	"retweeted": false,
	"coordinates": null,
	"entities": {
		"symbols": [],
		"user_mentions": [{
			"id": 827728690800893953,
			"indices": [0, 11],
			"id_str": "827728690800893953",
			"screen_name": "savingezra",
			"name": "Robert Kinsella \ud83c\udf83"
		}],
		"hashtags": [],
		"urls": []
	},
	"in_reply_to_screen_name": "EZRAPolitics",
	"in_reply_to_user_id": 110881593,
	"retweet_count": 0,
	"id_str": "817063217235103744",
	"favorited": false,
	"user": {
		"follow_request_sent": false,
		"has_extended_profile": true,
		"profile_use_background_image": true,
		"default_profile_image": false,
		"id": 3235321188,
		"profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
		"verified": false,
		"translator_type": "none",
		"profile_text_color": "333333",
		"profile_image_url_https": "https://pbs.twimg.com/profile_images/772166263594377216/hnXOjZzL_normal.jpg",
		"profile_sidebar_fill_color": "DDEEF6",
		"entities": {
			"description": {
				"urls": []
			}
		},
		"followers_count": 69,
		"profile_sidebar_border_color": "C0DEED",
		"id_str": "3235321188",
		"profile_background_color": "C0DEED",
		"listed_count": 0,
		"is_translation_enabled": false,
		"utc_offset": null,
		"statuses_count": 688,
		"description": "20 // Libra // Living",
		"friends_count": 81,
		"location": "Wylie, TX",
		"profile_link_color": "1DA1F2",
		"profile_image_url": "http://pbs.twimg.com/profile_images/772166263594377216/hnXOjZzL_normal.jpg",
		"following": false,
		"geo_enabled": false,
		"profile_banner_url": "https://pbs.twimg.com/profile_banners/3235321188/1448772731",
		"profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
		"screen_name": "_baiibai",
		"lang": "en",
		"profile_background_tile": false,
		"favourites_count": 106,
		"name": "Bailey Campbell",
		"notifications": false,
		"url": null,
		"created_at": "Wed Jun 03 19:43:10 +0000 2015",
		"contributors_enabled": false,
		"time_zone": null,
		"protected": false,
		"default_profile": true,
		"is_translator": false
	},
	"geo": null,
	"in_reply_to_user_id_str": "110881593",
	"lang": "und",
	"created_at": "Thu Jan 05 17:40:25 +0000 2017",
	"in_reply_to_status_id_str": "817060145805062144",
	"place": null
} 
{
	"contributors": null,
	"truncated": false,
	"text": "Guys, for real though. My love for Dinner from Blue Exorcist is quite alarming. I mean LOOK AT HIM!!! https://t.co/51o4zpGZ5E",
	"is_quote_status": false,
	"in_reply_to_status_id": null,
	"id": 813925998706171904,
	"favorite_count": 1,
	"source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
	"retweeted": false,
	"coordinates": null,
	"entities": {
		"symbols": [],
		"user_mentions": [],
		"hashtags": [],
		"urls": [],
		"media": [{
			"expanded_url": "https://twitter.com/_baiibai/status/813925998706171904/photo/1",
			"display_url": "pic.twitter.com/51o4zpGZ5E",
			"url": "https://t.co/51o4zpGZ5E",
			"media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C0ulX1HUoAAp0Yf.jpg",
			"id_str": "813925986483871744",
			"sizes": {
				"large": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"small": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"medium": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"thumb": {
					"h": 150,
					"resize": "crop",
					"w": 150
				}
			},
			"indices": [102, 125],
			"type": "photo",
			"id": 813925986483871744,
			"media_url": "http://pbs.twimg.com/tweet_video_thumb/C0ulX1HUoAAp0Yf.jpg"
		}]
	},
	"in_reply_to_screen_name": null,
	"in_reply_to_user_id": null,
	"retweet_count": 1,
	"id_str": "813925998706171904",
	"favorited": false,
	"user": {
		"follow_request_sent": false,
		"has_extended_profile": true,
		"profile_use_background_image": true,
		"default_profile_image": false,
		"id": 3235321188,
		"profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
		"verified": false,
		"translator_type": "none",
		"profile_text_color": "333333",
		"profile_image_url_https": "https://pbs.twimg.com/profile_images/772166263594377216/hnXOjZzL_normal.jpg",
		"profile_sidebar_fill_color": "DDEEF6",
		"entities": {
			"description": {
				"urls": []
			}
		},
		"followers_count": 69,
		"profile_sidebar_border_color": "C0DEED",
		"id_str": "3235321188",
		"profile_background_color": "C0DEED",
		"listed_count": 0,
		"is_translation_enabled": false,
		"utc_offset": null,
		"statuses_count": 688,
		"description": "20 // Libra // Living",
		"friends_count": 81,
		"location": "Wylie, TX",
		"profile_link_color": "1DA1F2",
		"profile_image_url": "http://pbs.twimg.com/profile_images/772166263594377216/hnXOjZzL_normal.jpg",
		"following": false,
		"geo_enabled": false,
		"profile_banner_url": "https://pbs.twimg.com/profile_banners/3235321188/1448772731",
		"profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
		"screen_name": "_baiibai",
		"lang": "en",
		"profile_background_tile": false,
		"favourites_count": 106,
		"name": "Bailey Campbell",
		"notifications": false,
		"url": null,
		"created_at": "Wed Jun 03 19:43:10 +0000 2015",
		"contributors_enabled": false,
		"time_zone": null,
		"protected": false,
		"default_profile": true,
		"is_translator": false
	},
	"geo": null,
	"in_reply_to_user_id_str": null,
	"possibly_sensitive": false,
	"lang": "en",
	"created_at": "Wed Dec 28 01:54:14 +0000 2016",
	"in_reply_to_status_id_str": null,
	"place": null,
	"extended_entities": {
		"media": [{
			"expanded_url": "https://twitter.com/_baiibai/status/813925998706171904/photo/1",
			"display_url": "pic.twitter.com/51o4zpGZ5E",
			"url": "https://t.co/51o4zpGZ5E",
			"media_url_https": "https://pbs.twimg.com/tweet_video_thumb/C0ulX1HUoAAp0Yf.jpg",
			"video_info": {
				"aspect_ratio": [25, 14],
				"variants": [{
					"url": "https://video.twimg.com/tweet_video/C0ulX1HUoAAp0Yf.mp4",
					"bitrate": 0,
					"content_type": "video/mp4"
				}]
			},
			"id_str": "813925986483871744",
			"sizes": {
				"large": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"small": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"medium": {
					"h": 280,
					"resize": "fit",
					"w": 500
				},
				"thumb": {
					"h": 150,
					"resize": "crop",
					"w": 150
				}
			},
			"indices": [102, 125],
			"type": "animated_gif",
			"id": 813925986483871744,
			"media_url": "http://pbs.twimg.com/tweet_video_thumb/C0ulX1HUoAAp0Yf.jpg"
		}]
	}
}


'''

# %%
timelines = []
tweet = []

append = False

for word in s.split():
    print word
    #print word
    if word == '"text":':
        #print word
        append = True
        
    if append == True:
        tweet.append(word)
        #print word
        
    if "is_quote_status" in word:
        del tweet[0]
        timelines.append(tweet)
        tweet = []
        append = False
        #break
            
            
#print timelines
# Out:
# {
# "contributors":
# null,
# "truncated":
# false,
# "text":
# "@SAVINGEZRA
# YESSSSS\ud83d\ude06\ud83d\ude06",
# "is_quote_status":
# false,
# "in_reply_to_status_id":
# 817060145805062144,
# "id":
# 817063217235103744,
# "favorite_count":
# 0,
# "source":
# "<a
# href="http://twitter.com/download/android"
# rel="nofollow">Twitter
# for
# Android</a>",
# "retweeted":
# false,
# "coordinates":
# null,
# "entities":
# {
# "symbols":
# [],
# "user_mentions":
# [{
# "id":
# 827728690800893953,
# "indices":
# [0,
# 11],
# "id_str":
# "827728690800893953",
# "screen_name":
# "savingezra",
# "name":
# "Robert
# Kinsella
# \ud83c\udf83"
# }],
# "hashtags":
# [],
# "urls":
# []
# },
# "in_reply_to_screen_name":
# "EZRAPolitics",
# "in_reply_to_user_id":
# 110881593,
# "retweet_count":
# 0,
# "id_str":
# "817063217235103744",
# "favorited":
# false,
# "user":
# {
# "follow_request_sent":
# false,
# "has_extended_profile":
# true,
# "profile_use_background_image":
# true,
# ...

# %%
directory = '../manual_tweets/'

filename = '@_baiibai.txt'

filename = directory+filename

with open(filename, "r") as tweets_file:
    for line in tweets_file:
        timeline = []
        tweet = []

        append = False

        for word in line.split():            
            if word == '"text":':
                append = True

            if append == True and word != '"is_quote_status":':
                tweet.append(word)

            if '"is_quote_status":' in word:
                del tweet[0]
                timeline.append(tweet)
                tweet = []
                append = False
                
print len(timeline)

print timeline
# Out:
# 631
# ...

# %%
def clean(timelines):
    i = 0
    l = 0
    for t in timelines:
        if '"urls":' in t or '"media":' in t or '[{"url":' in t:
            del timelines[i]
            l += 1
        i += 1
        
    return l

# %%
# doesnt catch all of the values on the first run for some reason
# takes a couple of loops of processign to get what we want

l = 100 
while l != 0:
    l = clean(timelines)


print l
print len(timelines)
# Out:
# 0
# 589

# %%
for tweet in timelines:
    print tweet
    print
# Out:
# ['"@SAVINGEZRA', 'YESSSSS\\ud83d\\ude06\\ud83d\\ude06",']
#
# ['"Guys,', 'for', 'real', 'though.', 'My', 'love', 'for', 'Dinner', 'from', 'Blue', 'Exorcist', 'is', 'quite', 'alarming.', 'I', 'mean', 'LOOK', 'AT', 'HIM!!!', 'https://t.co/51o4zpGZ5E",']
#
# ['"We', 'lost', 'amazing', 'people', 'the', 'beginning', 'of', '2016', 'and', 'we', 'lost', 'even', 'more', 'amazing', 'people!', 'WHY', 'TAKE', 'CARRIE', 'FISHER??!!",']
#
# ['"@Onision', 'you', 'and', 'Lainey', 'are', 'two', 'beautiful', 'human', 'beings\\ud83d\\ude3b\\u2764",']
#
# ['"RT', '@cool_as_heck:', 'Somebody', 'asked', 'me', 'to', 'make', 'a', 'trap', 'remix', 'of', 'the', 'Wii', 'intro', 'theme', 'so', 'https://t.co/o96qwhAy1I",']
#
# ['"Somebody', 'asked', 'me', 'to', 'make', 'a', 'trap', 'remix', 'of', 'the', 'Wii', 'intro', 'theme', 'so', 'https://t.co/o96qwhAy1I",']
#
# ['"RT', '@mermoneyy:', 'when', 'you', 'specifically', 'said', '\\"no', 'political', 'parties\\"', 'https://t.co/R6P5VDgzVK",']
#
# ...
